# %% [markdown]
# # Realizar Predicciones con Modelo Previamente Exportado

# %% [markdown]
# ## Importar Librerias

# %%
import os
import tensorflow as tf
import pandas as pd

# %% [markdown]
# ## Crear Variables Globales

# %%
dir = os.path.dirname(os.path.realpath('__file__'))

CLASS_OF_INCOME = [" <=50K", " >50K"]

# %% [markdown]
# ## Cargar Modelo
#
# Carga el modelo desde el directorio de exportación y crea una función de predicción.

# %%
predict_fn = tf.contrib.predictor.from_saved_model(dir + '/export/1536099145')
# Out:
# INFO:tensorflow:Restoring parameters from /notebooks/export/1536099145/variables/variables

# %% [markdown]
# ## Obtener Datos
#
# Obtener los datos nuevos en base a los cuales se desean hacer predicciones

# %%
# extraer datos previamente guardados
inputs = pd.read_csv('./testing_data/testing_data.csv')

# guardar resultados de prediccion (para este conjunto de datos si se cuenta con ellos)
true_results = inputs['income_bracket']

# quitar resultados de las columnas de datos
inputs = inputs.drop('income_bracket', axis=1)

# %% [markdown]
# ## Conversion de Input Data
#
# Convertir datos de entrada (input data) a strings serializados.

# %%
examples = []

for index, row in inputs.iterrows():
    feature = {}
    for col, value in row.iteritems():
        if 'int' in str(type(value)):
            feature[col] = tf.train.Feature(float_list=tf.train.FloatList(value=[value]))
        elif 'str' in str(type(value)):
            feature[col] = tf.train.Feature(bytes_list=tf.train.BytesList(value=[str.encode(value)]))
    
    example = tf.train.Example(
        features=tf.train.Features(
            feature=feature
        )
    )
    examples.append(example.SerializeToString())

# %% [markdown]
# ## Realizar predicciones

# %%
predictions = predict_fn({'inputs': examples})

# %%
# predictions format 

# {
#     'classes': 
#     array([
#         [b'0', b'1'],
#         [b'0', b'1'],
#         [b'0', b'1'],
#         ...,
#         [b'0', b'1'],
#         [b'0', b'1'],
#         [b'0', b'1']
#     ], dtype=object),
#     'scores': 
#     array([
#         [9.9974567e-01, 2.5436125e-04],
#         [5.6878764e-02, 9.4312125e-01],
#         [5.7067543e-01, 4.2932451e-01],
#         ...,
#         [9.8696136e-01, 1.3038697e-02],
#         [9.9976856e-01, 2.3141838e-04],
#         [3.3010733e-31, 1.0000000e+00]
#     ], dtype=float32)
# }

# %% [markdown]
# ## Procesar Predicciones
#
# Procesar las predicciones para obtener el resultado de predicción (CLASE DE INGRESO **<=50K** o **>50K**) y la probabilidad (%) para este resultado.
#
# En este caso se busca la clase con mayor probabilidad (mas cercana al 100%) y se agrega al DataFrame de **inputs** para identificar los resultados de cada fila de datos ingresados.

# %%
# diccionario que guarda los valores de predicción
probabilities = {'CLASS_OF_INCOME': [], 'PROBABILITY %': []}

for classes, scores in zip(predictions['classes'], predictions['scores']):
    '''
    la probabilidad mayor
    
    Ej:
    
    [5.6878764e-02, 9.4312125e-01]
    
    probabilidad mayor: 9.4312125e-01
    
    '''
    probability = float("%.2f" % (scores.max(axis=0) * 100))
    
    '''
    la posicion en la que se encuentra la probabilidad mayor en el np.ndarray()
    
    Ej:
    
    [5.6878764e-02, 9.4312125e-01]
    
    posicion: 1 
    
    '''
    index_of_max = list(scores).index(scores.max(axis=0))
    
    '''
    la clase a la que pertenece segun la posicion de la probabilidad mayor

    Ej:

    [b'0', b'1']

    posicion 1 --> pertenece a la clase 1
    
    '''
    class_of_max = list(classes)[index_of_max]
    
    # llenar el diccionario
    probabilities['CLASS_OF_INCOME'].append(CLASS_OF_INCOME[int(class_of_max)])
    probabilities['PROBABILITY %'].append(probability)
    
# convertir dict() a Pandas DataFrame
probabilities = pd.DataFrame(probabilities)

inputs['CLASS_OF_INCOME'] = probabilities['CLASS_OF_INCOME']
inputs['PROBABILITY %'] = probabilities['PROBABILITY %']

# %%
inputs
# Out:
#      age          workclass      education  education_num  \
# 0     25            Private   Some-college             10
# 1     51          Local-gov        Masters             14
# 2     32            Private     Assoc-acdm             12
# 3     51       Self-emp-inc      Bachelors             13
# 4     42            Private   Some-college             10
# 5     39            Private        HS-grad              9
# 6     24            Private        HS-grad              9
# 7     52            Private        HS-grad              9
# 8     58                  ?        1st-4th              2
# 9     43            Private        Masters             14
# 10    31            Private        HS-grad              9
# 11    28            Private        HS-grad              9
# 12    31        Federal-gov        Masters             14
# 13    61            Private        HS-grad              9
# 14    26            Private      Bachelors             13
# 15    46            Private      Bachelors             13
# 16    62                  ?        HS-grad              9
# 17    50            Private        Masters             14
# 18    18            Private           11th              7
# 19    23            Private      Bachelors             13
# 20    21            Private   Some-college             10
# 21    46            Private     Assoc-acdm             12
# 22    38            Private        HS-grad              9
# 23    53            Private           12th              8
# 24    53            Private        HS-grad              9
# 25    50            Private   Some-college             10
# 26    26            Private        HS-grad              9
# 27    46          Local-gov        Masters             14
# 28    44          Local-gov      Bachelors             13
# 29    36          Local-gov        Masters             14
# ..   ...                ...            ...            ...
# 531   30                  ?      Bachelors             13
# 532   34            Private      Doctorate             16
# 533   54            Private      Bachelors             13
# 534   37            Private   Some-college             10
# 535   22            Private           12th              8
# 536   34            Private      Bachelors             13
# 537   30            Private        HS-grad              9
# 538   38            Private      Bachelors             13
# 539   71                  ?      Doctorate             16
# 540   45          State-gov        HS-grad              9
# 541   41                  ?        HS-grad              9
# 542   72                  ?        HS-grad              9
# 543   45          Local-gov     Assoc-acdm             12
# 544   31            Private        Masters             14
# 545   39          Local-gov     Assoc-acdm             12
# 546   37            Private     Assoc-acdm             12
# 547   43            Private        HS-grad              9
# 548   65   Self-emp-not-inc    Prof-school             15
# 549   43          State-gov   Some-college             10
# 550   43   Self-emp-not-inc   Some-college             10
# 551   32            Private           10th              6
# 552   43            Private      Assoc-voc             11
# 553   32            Private        Masters             14
# 554   53            Private        Masters             14
# 555   22            Private   Some-college             10
# 556   27            Private     Assoc-acdm             12
# 557   40            Private        HS-grad              9
# 558   58            Private        HS-grad              9
# 559   22            Private        HS-grad              9
# 560   52       Self-emp-inc        HS-grad              9
#
#              marital_status          occupation     relationship  \
# 0                  Divorced       Other-service        Own-child
# 1        Married-civ-spouse      Prof-specialty          Husband
# 2        Married-civ-spouse   Machine-op-inspct          Husband
# 3        Married-civ-spouse     Exec-managerial          Husband
# 4                  Divorced               Sales    Not-in-family
# 5        Married-civ-spouse   Machine-op-inspct          Husband
# 6        Married-civ-spouse        Craft-repair          Husband
# 7                  Divorced        Adm-clerical        Unmarried
# 8     Married-spouse-absent                   ?        Unmarried
# 9        Married-civ-spouse      Prof-specialty          Husband
# 10       Married-civ-spouse   Machine-op-inspct          Husband
# 11       Married-civ-spouse               Sales          Husband
# 12       Married-civ-spouse     Exec-managerial          Husband
# 13       Married-civ-spouse        Craft-repair          Husband
# 14            Never-married      Prof-specialty        Own-child
# 15            Never-married       Other-service    Not-in-family
# 16       Married-civ-spouse                   ?          Husband
# 17                 Divorced      Prof-specialty    Not-in-family
# 18            Never-married        Adm-clerical        Own-child
# 19            Never-married               Sales    Not-in-family
# 20            Never-married               Sales        Own-child
# 21       Married-civ-spouse    Transport-moving          Husband
# 22                 Divorced               Sales        Unmarried
# 23                 Divorced     Farming-fishing        Own-child
# 24       Married-civ-spouse               Sales          Husband
# 25       Married-civ-spouse        Craft-repair          Husband
# 26            Never-married       Other-service        Unmarried
# 27                 Divorced      Prof-specialty    Not-in-family
# 28       Married-civ-spouse      Prof-specialty          Husband
# 29       Married-civ-spouse      Prof-specialty          Husband
# ..                      ...                 ...              ...
# 531           Never-married                   ?    Not-in-family
# 532      Married-civ-spouse      Prof-specialty          Husband
# 533      Married-civ-spouse     Exec-managerial          Husband
# 534                Divorced        Adm-clerical        Unmarried
# 535           Never-married     Protective-serv        Own-child
# 536           Never-married     Exec-managerial    Not-in-family
# 537           Never-married        Craft-repair    Not-in-family
# 538                Divorced      Prof-specialty        Unmarried
# 539      Married-civ-spouse                   ?          Husband
# 540               Separated        Adm-clerical        Own-child
# 541               Separated                   ?    Not-in-family
# 542      Married-civ-spouse                   ?          Husband
# 543                Divorced      Prof-specialty        Unmarried
# 544                Divorced       Other-service    Not-in-family
# 545      Married-civ-spouse        Adm-clerical             Wife
# 546                Divorced        Tech-support    Not-in-family
# 547      Married-civ-spouse   Machine-op-inspct          Husband
# 548           Never-married      Prof-specialty    Not-in-family
# 549                Divorced        Adm-clerical   Other-relative
# 550      Married-civ-spouse        Craft-repair          Husband
# 551      Married-civ-spouse   Handlers-cleaners          Husband
# 552      Married-civ-spouse               Sales          Husband
# 553           Never-married        Tech-support    Not-in-family
# 554      Married-civ-spouse     Exec-managerial          Husband
# 555           Never-married     Protective-serv    Not-in-family
# 556      Married-civ-spouse        Tech-support             Wife
# 557      Married-civ-spouse   Machine-op-inspct          Husband
# 558                 Widowed        Adm-clerical        Unmarried
# 559           Never-married        Adm-clerical        Own-child
# 560      Married-civ-spouse     Exec-managerial             Wife
#
#                     race   gender  capital_gain  capital_loss  hours_per_week  \
# 0                  Black     Male             0             0              38
# 1                  White     Male             0             0              80
# 2                  White     Male             0             0              62
# 3                  White     Male             0             0              25
# 4                  White     Male             0             0              50
# 5                  White     Male             0          1887              40
# 6                  White     Male             0             0              45
# 7                  White   Female             0          1741              38
# 8     Amer-Indian-Eskimo     Male             0             0              40
# 9                  White     Male             0             0              55
# 10                 White     Male             0             0              40
# 11                 White     Male             0             0              40
# 12                 White     Male          7688             0              60
# 13                 White     Male             0          2051              20
# 14                 White   Female             0             0              40
# 15                 White     Male             0             0              40
# 16                 White     Male             0             0              40
# 17                 White   Female             0             0              35
# 18                 White   Female             0             0               5
# 19                 White     Male             0             0              48
# 20                 White   Female             0          1762              28
# 21                 Other     Male             0             0              36
# 22                 White   Female             0             0              40
# 23                 White     Male             0             0              40
# 24                 White     Male             0             0              40
# 25                 White     Male             0             0              40
# 26                 White     Male             0             0              25
# 27                 White   Female          8614             0              55
# 28                 White     Male             0             0              40
# 29                 White     Male             0             0              50
# ..                   ...      ...           ...           ...             ...
# 531   Asian-Pac-Islander   Female             0             0              99
# 532                White     Male             0             0              60
# 533   Asian-Pac-Islander     Male             0             0              50
# 534                White   Female             0             0              39
# 535                Black     Male             0             0              35
# 536                White   Female             0             0              55
# 537                Black     Male             0             0              46
# 538                Black   Female         15020             0              45
# 539                White     Male             0             0              10
# 540                White   Female             0             0              40
# 541                Black   Female             0             0              32
# 542                White     Male             0             0              25
# 543                White   Female             0             0              48
# 544                Other   Female             0             0              30
# 545                White   Female             0             0              20
# 546                White   Female             0             0              40
# 547                White     Male             0             0              40
# 548                White     Male          1086             0              60
# 549                White   Female             0             0              40
# 550                White     Male             0             0              50
# 551   Amer-Indian-Eskimo     Male             0             0              40
# 552                White     Male             0             0              45
# 553   Asian-Pac-Islander     Male             0             0              11
# 554                White     Male             0             0              40
# 555                White     Male             0             0              40
# 556                White   Female             0             0              38
# 557                White     Male             0             0              40
# 558                White   Female             0             0              40
# 559                White     Male             0             0              20
# 560                White   Female         15024             0              40
#
#      native_country CLASS_OF_INCOME  PROBABILITY %
# 0     United-States           <=50K          99.98
# 1     United-States            >50K          95.61
# 2     United-States           <=50K          55.39
# 3     United-States            >50K          75.53
# 4     United-States           <=50K          93.50
# 5     United-States            >50K          99.64
# 6     United-States           <=50K          79.08
# 7     United-States            >50K          90.86
# 8     United-States           <=50K          99.66
# 9     United-States            >50K          88.81
# 10    United-States           <=50K          86.45
# 11    United-States           <=50K          75.68
# 12    United-States            >50K          99.93
# 13    United-States            >50K          99.88
# 14    United-States           <=50K          99.46
# 15    United-States           <=50K          97.49
# 16    United-States           <=50K          83.99
# 17    United-States           <=50K          80.21
# 18    United-States           <=50K         100.00
# 19    United-States           <=50K          91.17
# 20    United-States           <=50K          59.16
# 21    United-States           <=50K          61.43
# 22    United-States           <=50K          98.52
# 23    United-States           <=50K          99.96
# 24    United-States           <=50K          55.90
# 25    United-States           <=50K          54.83
# 26    United-States           <=50K          99.92
# 27    United-States            >50K          97.83
# 28    United-States            >50K          66.26
# 29    United-States            >50K          78.06
# ..              ...             ...            ...
# 531   United-States           <=50K          84.04
# 532   United-States            >50K          94.77
# 533           Japan            >50K          93.67
# 534   United-States           <=50K          98.80
# 535   United-States           <=50K          99.90
# 536   United-States           <=50K          76.87
# 537   United-States           <=50K          98.10
# 538   United-States            >50K          99.76
# 539   United-States            >50K          57.42
# 540   United-States           <=50K          99.90
# 541   United-States           <=50K          99.64
# 542   United-States           <=50K          87.39
# 543   United-States           <=50K          96.15
# 544   United-States           <=50K          98.47
# 545   United-States           <=50K          72.95
# 546   United-States           <=50K          92.90
# 547          Mexico           <=50K          89.91
# 548   United-States            >50K          71.29
# 549   United-States           <=50K          98.59
# 550   United-States           <=50K          68.11
# 551   United-States           <=50K          96.63
# 552   United-States            >50K          58.08
# 553          Taiwan           <=50K          91.45
# 554   United-States            >50K          89.79
# 555   United-States           <=50K          96.83
# 556   United-States            >50K          66.19
# 557   United-States           <=50K          82.20
# 558   United-States           <=50K          98.25
# 559   United-States           <=50K          99.98
# 560   United-States            >50K          99.99
#
# [561 rows x 15 columns]
